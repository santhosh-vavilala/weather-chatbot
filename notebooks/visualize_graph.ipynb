# %% [markdown]
# # Weather Chatbot Graph Visualization
#
# This notebook visualizes the production graph defined in `graph.py`. It does not duplicate or modify the application logic.

# %%
from pathlib import Path
import sys

# Make the project root importable whether the notebook runs from the root or notebooks folder.
project_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from graph import build_graph

# %%
from IPython.display import Image, display

weather_graph = build_graph()
display(Image(weather_graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ## Mermaid definition
#
# The next cell displays the Mermaid source used to render the graph.

# %%
from IPython.display import Markdown, display

mermaid_definition = weather_graph.get_graph().draw_mermaid()
display(Markdown(f"```mermaid\n{mermaid_definition}\n```"))
# Out:
# ```mermaid
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	understand(understand)
# 	ask_city(ask_city)
# 	help(help)
# 	resolve_city(resolve_city)
# 	get_weather(get_weather)
# 	answer(answer)
# 	remember_reply(remember_reply)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> understand;
# 	answer --> remember_reply;
# 	ask_city --> remember_reply;
# 	get_weather --> answer;
# 	help --> remember_reply;
# 	resolve_city -.-> answer;
# 	resolve_city -.-> get_weather;
# 	understand -.-> ask_city;
# 	understand -.-> help;
# 	understand -.-> resolve_city;
# 	remember_reply --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
#
# ```
